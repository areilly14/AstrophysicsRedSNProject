# %% [markdown]
# ## Extinction Curves

# %% [markdown]
# Import

# %%
import numpy as np
from astropy.modeling.models import BlackBody
import astropy.units as u
import matplotlib.pyplot as plt
from dust_extinction.parameter_averages import G23
from dust_extinction.parameter_averages import F19
from dust_extinction.parameter_averages import F99

##Second program
import extinction

# %%
# wavelengths and spectrum are 1D arrays
# wavelengths between 1000 and 30000 A
wavelengths = np.logspace(np.log10(0.1), np.log10(30.0), num=1000)*u.micron
wavelengths2 = np.logspace(np.log10(0.3), np.log10(3.0), num=1000)*u.micron
bb_lam = BlackBody(10000*u.K, scale=1.0 * u.erg / (u.cm ** 2 * u.AA * u.s * u.sr))
spectrum = bb_lam(wavelengths2)

# %%
# define the model
extG23 = G23(Rv=1.49)
extF19a = F19(Rv=2.07)
extF99a = F99(Rv=2.07)
extF99b = F99(Rv=2.58)
extF19b = F19(Rv=2.58)

# %%
# unextinguish (deredden) the spectrum
# Av = 1.55 = R(V) * E(B-V) = 3.1 * 0.5
spectrum_extG23 = spectrum_ext*extG23.extinguish(wavelengths, Av=1.87)
spectrum_extF19a = spectrum*extF19a.extinguish(wavelengths2, Av=1.76)
spectrum_extF99a = spectrum*extF99a.extinguish(wavelengths2, Av=1.76)
spectrum_extF19b = spectrum*extF19b.extinguish(wavelengths2, Av=2.00)
spectrum_extF99b = spectrum*extF99b.extinguish(wavelengths2, Av=2.00)

# %%
plt.yscale("log")
plt.xscale("log")
plt.xlabel('Wavelength')
plt.ylabel('Flux')
plt.title('Extinction of SN2009I comparing F99 and F19')
plt.plot(wavelengths, spectrum_extG23, color = 'r')
plt.plot(wavelengths2, spectrum_extF19a, 'r', label = rf"F19 $A_v$ = 1.76 $R_v$ = 2.07")
plt.plot(wavelengths2, spectrum_extF99a,'--y', label = rf"F99 $A_v$ = 1.76 $R_v$ = 2.07")
plt.plot(wavelengths2, spectrum_extF99b,  'b', label = rf"F99 $A_v$ = 2.00 $R_v$ = 2.58")
plt.plot(wavelengths2, spectrum_extF19b,  '--g', label = rf"F19 $A_v$ = 2.00 $R_v$ = 2.58")
plt.legend()

# %% [markdown]
# ## Second Program

# %%
values = [1000,2000,3000,4000,5000,6000,7000,8000,9000]

# %%
wave = np.array(values)  # wavelength in Angstroms
wave = np.logspace(np.log10(0.3), np.log10(3.0), num=1000)
# Out:
# array([7.11786421e+11, 7.06881231e+11, 7.02009844e+11, 6.97172026e+11,
#        6.92367547e+11, 6.87596176e+11, 6.82857686e+11, 6.78151850e+11,
#        6.73478443e+11, 6.68837241e+11, 6.64228022e+11, 6.59650567e+11,
#        6.55104655e+11, 6.50590071e+11, 6.46106597e+11, 6.41654020e+11,
#        6.37232127e+11, 6.32840705e+11, 6.28479546e+11, 6.24148441e+11,
#        6.19847182e+11, 6.15575564e+11, 6.11333382e+11, 6.07120435e+11,
#        6.02936519e+11, 5.98781436e+11, 5.94654987e+11, 5.90556974e+11,
#        5.86487201e+11, 5.82445473e+11, 5.78431598e+11, 5.74445384e+11,
#        5.70486640e+11, 5.66555176e+11, 5.62650804e+11, 5.58773339e+11,
#        5.54922594e+11, 5.51098385e+11, 5.47300530e+11, 5.43528847e+11,
#        5.39783155e+11, 5.36063276e+11, 5.32369031e+11, 5.28700244e+11,
#        5.25056740e+11, 5.21438344e+11, 5.17844883e+11, 5.14276185e+11,
#        5.10732080e+11, 5.07212398e+11, 5.03716972e+11, 5.00245633e+11,
# ...

# %%
plt.yscale("log")
#plt.xscale("log")
plt.plot(wave, extinction.fitzpatrick99(wave, 2.11, 2.54), color = 'r')
plt.plot(wave, extinction.fitzpatrick19(wave, 2, 2.54), color = 'b')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[34], line 4
#       2 #plt.xscale("log")
#       3 plt.plot(wave, extinction.fitzpatrick99(wave, 2.11, 2.54), color = 'r')
# ----> 4 plt.plot(wave, extinction.fitzpatrick19(wave, 2, 2.54), color = 'b')
#
# AttributeError: module 'extinction' has no attribute 'fitzpatrick19'
