# %%
import pylab
fig = pylab.figure()
figlegend = pylab.figure(figsize=(3,2))
ax = fig.add_subplot(111)
lines = ax.plot(range(10), pylab.randn(10), range(10), pylab.randn(10))
figlegend.legend(lines, ('one', 'two'), 'center')
fig.show()
figlegend.show()
figlegend.savefig('legend.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 6
#       4 ax = fig.add_subplot(111)
#       5 lines = ax.plot(range(10), pylab.randn(10), range(10), pylab.randn(10))
# ----> 6 figlegend.legend(lines, ('one', 'two'), 'center')
#       7 fig.show()
#       8 figlegend.show()
#
# File ~/miniforge3/envs/bayesn/lib/python3.11/site-packages/matplotlib/figure.py:1076, in FigureBase.legend(self, *args, **kwargs)
#     965 @_docstring.dedent_interpd
#     966 def legend(self, *args, **kwargs):
#     967     """
#     968     Place a legend on the figure.
#     969
#    (...)
#    1073     :ref:`legend_guide` for details.
#    1074     """
# -> 1076     handles, labels, kwargs = mlegend._parse_legend_args(self.axes, *args, **kwargs)
#    1077     # explicitly set the bbox transform if the user hasn't.
#    1078     kwargs.setdefault("bbox_transform", self.transSubfigure)
#
# File ~/miniforge3/envs/bayesn/lib/python3.11/site-packages/matplotlib/legend.py:1383, in _parse_legend_args(axs, handles, labels, *args, **kwargs)
#    1380     handles, labels = args[:2]
#    1382 else:
# -> 1383     raise _api.nargs_error('legend', '0-2', len(args))
#    1385 return handles, labels, kwargs
#
# TypeError: legend() takes 0-2 positional arguments but 3 were given
